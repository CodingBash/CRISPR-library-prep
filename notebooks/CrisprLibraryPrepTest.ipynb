# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(1, '../crispr_library_prep/crispr_library_prep')
import CrisprLibraryPrep as crispr_library_prep

# %%
import numpy as np

# %%
from typing import List, Tuple
gDNA_amounts_low_moi: Tuple[List[int], int]= ([2, 1.25, 0.75, 3, 1.8, 1.5], 1)
gDNA_amounts_high_moi: Tuple[List[int], int]= ([2, 1, 0.5, 3, 1.5, 5, 0.8, 0.6], 3)

# %%
crispr_library_prep.get_target_coverage_per_sample(gDNA_amounts_low_moi, guide_library_size=795, target_coverage_input=400, perfection_rate=0.62)
# Out:
# gDNA: 2; MOI: 1; Desired Coverage=400, Suggested Coverage=212, Max Coverage=236,
#  Reads for Desired Coverage=4668125, Reads for Suggested Coverage=761713
# c:\Users\bbece\AppData\Local\pypoetry\Cache\virtualenvs\crispr-library-prep-pOktaiIB-py3.8\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 crispr_library_prep.get_target_coverage_per_sample(gDNA_amounts_low_moi, guide_library_size=795, target_coverage_input=400, perfection_rate=0.62)
#
# ...

# %%
erage_per_sample(gDNA_amounts_low_moi, guide_library_size=795, target_coverage_input=400, perfection_rate=0.62)
